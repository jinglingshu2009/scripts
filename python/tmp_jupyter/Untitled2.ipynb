# %%
#!/usr/bin/python
#^_^ coding:utf-8 ^_^
#Filename:get_systeminfo.py
import psutil
import sys
#reload(sys)
#sys.setdefaultencoding('utf-8')

cpu = psutil.cpu_times(percpu=True)
cpu1 = psutil.cpu_times()
nic = psutil.net_connections
#nic = psutil.net_connections(kind='inet')
print  psutil.net_connections()
K=1
#for item_nic in nic :
#    print K,item_nic
#    K=K+1
# Out:
# [sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=50907), raddr=addr(ip='127.0.0.1', port=50908), status='ESTABLISHED', pid=28608), sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=50804), raddr=addr(ip='127.0.0.1', port=50806), status='ESTABLISHED', pid=28608), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=60490), raddr=(), status='NONE', pid=4556), sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=50388), raddr=addr(ip='127.0.0.1', port=50387), status='ESTABLISHED', pid=27368), sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=6942), raddr=(), status='LISTEN', pid=7572), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=52644), raddr=(), status='NONE', pid=4556), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=65467), raddr=(), status='NONE', pid=4392), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=59947), raddr=(), status='NONE', pid=4392), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=60489), raddr=(), status='NONE', pid=4556), sconn(fd=-1, family=23, type=2, laddr=addr(ip='::1', port=64338), raddr=(), status='NONE', pid=4364), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=50485), raddr=(), status='NONE', pid=4392), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=52387), raddr=(), status='NONE', pid=4556), sconn(fd=-1, family=2, type=2, laddr=addr(ip='192.168.1.109', port=2177), raddr=(), status='NONE', pid=4364), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=58658), raddr=(), status='NONE', pid=4556), sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=50314), raddr=addr(ip='127.0.0.1', port=50411), status='ESTABLISHED', pid=27368), sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=50764), raddr=addr(ip='127.0.0.1', port=50743), status='ESTABLISHED', pid=8240), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=60911), raddr=(), status='NONE', pid=4392), sconn(fd=-1, family=2, type=2, laddr=addr(ip='192.168.7.2', port=2177), raddr=(), status='NONE', pid=4364), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=57412), raddr=(), status='NONE', pid=4392), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=56510), raddr=(), status='NONE', pid=4556), sconn(fd=-1, family=2, type=1, laddr=addr(ip='0.0.0.0', port=18899), raddr=(), status='LISTEN', pid=3728), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=63387), raddr=(), status='NONE', pid=4556), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=56664), raddr=(), status='NONE', pid=4556), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=4500), raddr=(), status='NONE', pid=1056), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=56170), raddr=(), status='NONE', pid=4556), sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=61131), raddr=addr(ip='127.0.0.1', port=61130), status='ESTABLISHED', pid=21212), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=62778), raddr=(), status='NONE', pid=4392), sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=50412), raddr=addr(ip='127.0.0.1', port=50413), status='ESTABLISHED', pid=8240), sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=50795), raddr=addr(ip='127.0.0.1', port=50794), status='ESTABLISHED', pid=28608), sconn(fd=-1, family=23, type=2, laddr=addr(ip='::', port=63514), raddr=(), status='NONE', pid=2244), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=57749), raddr=(), status='NONE', pid=4392), sconn(fd=-1, family=23, type=1, laddr=addr(ip='::', port=445), raddr=(), status='LISTEN', pid=4), sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=50402), raddr=addr(ip='127.0.0.1', port=50403), status='ESTABLISHED', pid=27368), sconn(fd=-1, family=2, type=2, laddr=addr(ip='0.0.0.0', port=2425), raddr=(), status='NONE', pid=17972), sconn(fd=-1, family=2, type=1, laddr=addr(ip='127.0.0.1', port=52826), ra ...
