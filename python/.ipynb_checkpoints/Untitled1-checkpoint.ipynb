# %%
import time
for xx  in range (1,100):
    print time.localtime.time.struct_time


#help('time')
# Out:
# time.struct_time(tm_year=2018, tm_mon=3, tm_mday=15, tm_hour=23, tm_min=22, tm_sec=50, tm_wday=3, tm_yday=74, tm_isdst=0)
# time.struct_time(tm_year=2018, tm_mon=3, tm_mday=15, tm_hour=23, tm_min=22, tm_sec=50, tm_wday=3, tm_yday=74, tm_isdst=0)
# time.struct_time(tm_year=2018, tm_mon=3, tm_mday=15, tm_hour=23, tm_min=22, tm_sec=50, tm_wday=3, tm_yday=74, tm_isdst=0)
# time.struct_time(tm_year=2018, tm_mon=3, tm_mday=15, tm_hour=23, tm_min=22, tm_sec=50, tm_wday=3, tm_yday=74, tm_isdst=0)
# time.struct_time(tm_year=2018, tm_mon=3, tm_mday=15, tm_hour=23, tm_min=22, tm_sec=50, tm_wday=3, tm_yday=74, tm_isdst=0)
# time.struct_time(tm_year=2018, tm_mon=3, tm_mday=15, tm_hour=23, tm_min=22, tm_sec=50, tm_wday=3, tm_yday=74, tm_isdst=0)
# time.struct_time(tm_year=2018, tm_mon=3, tm_mday=15, tm_hour=23, tm_min=22, tm_sec=50, tm_wday=3, tm_yday=74, tm_isdst=0)
# time.struct_time(tm_year=2018, tm_mon=3, tm_mday=15, tm_hour=23, tm_min=22, tm_sec=50, tm_wday=3, tm_yday=74, tm_isdst=0)
# ...
